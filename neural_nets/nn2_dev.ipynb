# %%
import numpy as np
import math
from sklearn import datasets
from sklearn import preprocessing

# %%
# creating: neural net for regression
# 2 features
# 1 hidden layer, 2 nodes, leaky-ReLu activation
# MSE loss function, no regularization

house_sk_data = datasets.load_boston()
# size of training and cross validation sets
m_train = 400
m_cv = 506 - m_train

# training set, using features:
# B 1000(Bk - 0.63)^2, LSTAT % lower status of the population
# scaled for zero mean and unit variance
house_sk_train = preprocessing.scale(house_sk_data.data[:m_train, 10:12])
house_sk_train_bias = np.column_stack([np.ones((m_train, 1)), house_sk_train])

# CV set
house_sk_cv = preprocessing.scale(house_sk_data.data[m_train:, 10:12])
house_sk_cv_bias = np.column_stack([np.ones((m_cv, 1)), house_sk_cv])

# target set
house_sk_target = house_sk_data.target[:m_train]

# %%
#randomly initialize weights for first and second layer
weights = np.random.rand(2,3)
weights2 = np.random.rand(1,3)

# %%
# Forward and backward propagates for a given training example _i_
def propagate(i):
    global weights2, weights

    #learning rate
    a = 0.009

    # z for second layer and activation (leaky-ReLu)
    z2 = np.dot(weights, np.transpose(house_sk_train_bias[i, :]))
    print('z2: ', z2)
    a2 = np.where(z2 > 0, z2, z2 * .01)
    print('a2: ', a2)
    # add bias unit for second layer
    a2_bias = np.concatenate((np.ones(1), a2))
    # z for third layer and final activation (ReLu)
    z3 = np.dot(weights2, a2_bias)
    hypot = z3
    #hypot = np.maximum(0, z3)

    #print(f'Prediction: {z3}')

    # Backpropagates to accumulate partials and deltas
    # Delta for third layer (mean squared error)
    delta3 =  hypot - house_sk_target[i]
    # derivative of error w.r.t weights, second layer
    layer2partials = np.multiply(delta3, a2_bias)

    # derivative of error w.r.t weights, first layer
    # big_delta2 without bias
    delta2 = np.multiply(delta3, a2)
    delta2_matrix = np.column_stack([delta2, delta2, delta2])
    feat_bias_matrix = np.row_stack([house_sk_train_bias[i,:], house_sk_train_bias[i,:]])
    layer1partials = np.multiply(delta2_matrix, feat_bias_matrix)

    weights2 = weights2 - a*layer2partials
    weights = weights - a*layer1partials

# %%
# Train weights
for i in range(0, m_train):
    propagate(i)

# fix: underfitting with small learning rate, overflow with large learning rate
# Out:
# z2:  [ 0.29332464 -0.43389722]
# a2:  [ 0.29332464 -0.00433897]
# z2:  [0.56667022 0.66440049]
# a2:  [0.56667022 0.66440049]
# z2:  [0.58215727 0.74622091]
# a2:  [0.58215727 0.74622091]
# z2:  [0.85193159 1.40479236]
# a2:  [0.85193159 1.40479236]
# z2:  [1.20386779 1.92025995]
# a2:  [1.20386779 1.92025995]
# z2:  [1.54028551 2.53187981]
# a2:  [1.54028551 2.53187981]
# z2:  [1.4022564  0.96549863]
# a2:  [1.4022564  0.96549863]
# z2:  [2.02494718 1.40104905]
# a2:  [2.02494718 1.40104905]
# z2:  [2.51901407 1.69040085]
# a2:  [2.51901407 1.69040085]
# z2:  [2.79283269 1.87462551]
# a2:  [2.79283269 1.87462551]
# z2:  [3.39502127 2.313424  ]
# a2:  [3.39502127 2.313424  ]
# z2:  [3.4395804  2.36800124]
# a2:  [3.4395804  2.36800124]
# z2:  [3.36376372 2.2822888 ]
# a2:  [3.36376372 2.2822888 ]
# z2:  [1.79014641 4.23612419]
# a2:  [1.79014641 4.23612419]
# z2:  [1.10326152 3.74353249]
# a2:  [1.10326152 3.74353249]
# z2:  [1.82482265 4.45202299]
# a2:  [1.82482265 4.45202299]
# z2:  [1.406727  4.0483654]
# a2:  [1.406727  4.0483654]
# z2:  [1.57592541 4.54421314]
# a2:  [1.57592541 4.54421314]
# z2:  [-2.79284249  0.68919436]
# a2:  [-0.02792842  0.68919436]
# z2:  [1.60070939 4.47928463]
# a2:  [1.60070939 4.47928463]
# z2:  [0.87226636 3.75914006]
# a2:  [0.87226636 3.75914006]
# z2:  [1.50162321 3.96772985]
# a2:  [1.50162321 3.96772985]
# z2:  [1.75375461 4.2630415 ]
# a2:  [1.75375461 4.2630415 ]
# z2:  [1.43631545 3.67007199]
# a2:  [1.43631545 3.67007199]
# z2:  [1.35356124 3.47562947]
# a2:  [1.35356124 3.47562947]
# z2:  [-2.49426592  1.00784502]
# a2:  [-0.02494266  1.00784502]
# z2:  [0.61474525 3.2451195 ]
# a2:  [0.61474525 3.2451195 ]
# z2:  [-2.32886934  1.8439412 ]
# a2:  [-0.02328869  1.8439412 ]
# z2:  [1.13046431 4.04031022]
# a2:  [1.13046431 4.04031022]
# z2:  [0.81908883 3.95514805]
# a2:  [0.81908883 3.95514805]
# z2:  [0.04992824 3.98586003]
# a2:  [0.04992824 3.98586003]
# z2:  [0.75053432 3.97061988]
# a2:  [0.75053432 3.97061988]
# z2:  [-5.43728999  0.78911709]
# a2:  [-0.0543729   0.78911709]
# z2:  [-0.08087307  3.62720451]
# a2:  [-8.08730698e-04  3.62720451e+00]
# z2:  [-4.82611729  1.80629451]
# a2:  [-0.04826117  1.80629451]
# z2:  [2.34753404 3.61882652]
# a2:  [2.34753404 3.61882652]
# z2:  [1.49141335 3.41521862]
# a2:  [1.49141335 3.41521862]
# z2:  [2.37380129 3.69784849]
# a2:  [2.37380129 3.69784849]
# z2:  [2.24491076 3.699888  ]
# a2:  [2.24491076 3.699888  ]
# z2:  [2.83825041 3.56735727]
# a2:  [2.83825041 3.56735727]
# z2:  [3.10136938 3.89851986]
# a2:  [3.10136938 3.89851986]
# z2:  [3.06170565 3.94175349]
# a2:  [3.06170565 3.94175349]
# z2:  [2.92844274 3.86541626]
# a2:  [2.92844274 3.86541626]
# z2:  [3.42181676 3.98152545]
# a2:  [3.42181676 3.98152545]
# z2:  [3.05441902 3.76043471]
# a2:  [3.05441902 3.76043471]
# z2:  [3.27630103 3.70389983]
# a2:  [3.27630103 3.70389983]
# z2:  [3.07840006 3.48017027]
# a2:  [3.07840006 3.48017027]
# z2:  [2.8153416  3.34593197]
# a2:  [2.8153416  3.34593197]
# z2:  [2.87608321 3.24433685]
# a2:  [2.87608321 3.24433685]
# z2:  [2.70827043 3.05503733]
# a2:  [2.70827043 3.05503733]
# z2:  [3.09322741 2.58153267]
# a2:  [3.09322741 2.58153267]
# z2:  [3.11111806 2.63906558]
# a2:  [3.11111806 2.63906558]
# z2:  [3.33230799 2.74647541]
# a2:  [3.33230799 2.74647541]
# z2:  [3.58161993 2.95195735]
# a2:  [3.58161993 2.95195735]
# z2:  [1.72733173 4.69893289]
# a2:  [1.72733173 4.69893289]
# z2:  [3.04956557 3.23424545]
# a2:  [3.04956557 3.23424545]
# z2:  [3.8630679  3.58181153]
# a2:  [3.8630679  3.58181153]
# z2:  [4.64337297 2.8268355 ]
# a2:  [4.64337297 2.8268355 ]
# z2:  [2.30215922 4.07740159]
# a2:  [2.30215922 4.07740159]
# z2:  [2.5482335  4.05034342]
# a2:  [2.5482335  4.05034342]
# z2:  [2.22895457 3.65994943]
# a2:  [2.22895457 3.65994943]
# z2:  [1.30775978 3.30446917]
# a2:  [1.30775978 3.30446917]
# z2:  [2.17443455 3.42270433]
# a2:  [2.17443455 3.42270433]
# z2:  [2.18089717 3.51827029]
# a2:  [2.18089717 3.51827029]
# z2:  [2.95134073 3.59867111]
# a2:  [2.95134073 3.59867111]
# z2:  [5.03498206 3.63481831]
# a2:  [5.03498206 3.63481831]
# z2:  [4.25974033 3.07516133]
# a2:  [4.25974033 3.07516133]
# z2:  [2.67413966 3.65670309]
# a2:  [2.67413966 3.65670309]
# z2:  [2.7136833  3.67581133]
# a2:  [2.7136833  3.67581133]
# z2:  [2.56536124 3.47490215]
# a2:  [2.56536124 3.47490215]
# z2:  [1.8943701  3.48566144]
# a2:  [1.8943701  3.48566144]
# z2:  [1.72151501 3.65088754]
# a2:  [1.72151501 3.65088754]
# z2:  [2.37243784 3.86589414]
# a2:  [2.37243784 3.86589414]
# z2:  [1.78715122 3.76430995]
# a2:  [1.78715122 3.76430995]
# z2:  [2.80633351 3.85419958]
# a2:  [2.80633351 3.85419958]
# z2:  [2.30033517 3.75423582]
# a2:  [2.30033517 3.75423582]
# z2:  [1.86183848 3.63357644]
# a2:  [1.86183848 3.63357644]
# z2:  [2.42993135 3.7302584 ]
# a2:  [2.42993135 3.7302584 ]
# z2:  [2.36824614 3.66800692]
# a2:  [2.36824614 3.66800692]
# z2:  [2.77663754 3.73513827]
# a2:  [2.77663754 3.73513827]
# z2:  [2.61529471 3.7421448 ]
# a2:  [2.61529471 3.7421448 ]
# z2:  [2.75541444 4.01039914]
# a2:  [2.75541444 4.01039914]
# z2:  [2.79293321 3.99586245]
# a2:  [2.79293321 3.99586245]
# z2:  [2.53067821 3.95463223]
# a2:  [2.53067821 3.95463223]
# z2:  [2.96922978 3.78565213]
# a2:  [2.96922978 3.78565213]
# z2:  [2.76244685 3.735877  ]
# a2:  [2.76244685 3.735877  ]
# z2:  [3.021641   3.90225047]
# a2:  [3.021641   3.90225047]
# z2:  [2.89430343 3.77743448]
# a2:  [2.89430343 3.77743448]
# z2:  [3.17938119 3.45455342]
# a2:  [3.17938119 3.45455342]
# z2:  [3.15966261 3.46526278]
# a2:  [3.15966261 3.46526278]
# z2:  [3.16694627 3.62340795]
# a2:  [3.16694627 3.62340795]
# z2:  [3.1552088  3.55401833]
# a2:  [3.1552088  3.55401833]
# z2:  [3.00218038 3.64603402]
# a2:  [3.00218038 3.64603402]
# z2:  [3.03810158 3.63164235]
# a2:  [3.03810158 3.63164235]
# z2:  [3.11123393 3.69448964]
# a2:  [3.11123393 3.69448964]
# z2:  [1.37481564 3.13071255]
# a2:  [1.37481564 3.13071255]
# z2:  [2.96253507 3.69600002]
# a2:  [2.96253507 3.69600002]
# z2:  [3.07298668 3.59417152]
# a2:  [3.07298668 3.59417152]
# z2:  [3.40018254 4.12537292]
# a2:  [3.40018254 4.12537292]
# z2:  [4.02706856 4.73079932]
# a2:  [4.02706856 4.73079932]
# z2:  [2.59756992 5.53858034]
# a2:  [2.59756992 5.53858034]
# z2:  [2.08482618 4.37253492]
# a2:  [2.08482618 4.37253492]
# z2:  [-12.46487747   2.16963497]
# a2:  [-0.12464877  2.16963497]
# z2:  [2.02129223 4.33131707]
# a2:  [2.02129223 4.33131707]
# z2:  [1.54377287 3.51923151]
# a2:  [1.54377287 3.51923151]
# z2:  [1.57280152 3.41569195]
# a2:  [1.57280152 3.41569195]
# z2:  [1.60549662 3.2923914 ]
# a2:  [1.60549662 3.2923914 ]
# z2:  [1.22819956 3.43252622]
# a2:  [1.22819956 3.43252622]
# z2:  [1.59671649 3.34648696]
# a2:  [1.59671649 3.34648696]
# z2:  [1.3995392  3.40040557]
# a2:  [1.3995392  3.40040557]
# z2:  [1.48551731 3.3122598 ]
# a2:  [1.48551731 3.3122598 ]
# z2:  [3.46966147 3.32782824]
# a2:  [3.46966147 3.32782824]
# z2:  [3.34103325 3.24632799]
# a2:  [3.34103325 3.24632799]
# z2:  [3.23374643 3.01343244]
# a2:  [3.23374643 3.01343244]
# z2:  [2.77770553 3.1129895 ]
# a2:  [2.77770553 3.1129895 ]
# z2:  [0.91128567 4.18266442]
# a2:  [0.91128567 4.18266442]
# z2:  [2.90115787 2.89833269]
# a2:  [2.90115787 2.89833269]
# z2:  [2.9947075  2.91147372]
# a2:  [2.9947075  2.91147372]
# z2:  [0.64203449 4.27078074]
# a2:  [0.64203449 4.27078074]
# z2:  [2.84382353 2.99475463]
# a2:  [2.84382353 2.99475463]
# z2:  [1.98451212 3.09734636]
# a2:  [1.98451212 3.09734636]
# z2:  [1.59259435 3.52651472]
# a2:  [1.59259435 3.52651472]
# z2:  [1.62703089 3.55328609]
# a2:  [1.62703089 3.55328609]
# z2:  [1.31933849 3.78808868]
# a2:  [1.31933849 3.78808868]
# z2:  [1.65794086 3.44441343]
# a2:  [1.65794086 3.44441343]
# z2:  [1.88740275 3.28946282]
# a2:  [1.88740275 3.28946282]
# z2:  [0.86123112 4.02373703]
# a2:  [0.86123112 4.02373703]
# z2:  [1.04076449 3.15440277]
# a2:  [1.04076449 3.15440277]
# z2:  [1.23872259 3.02965417]
# a2:  [1.23872259 3.02965417]
# z2:  [1.29732399 3.17298084]
# a2:  [1.29732399 3.17298084]
# z2:  [1.1094576  2.94904084]
# a2:  [1.1094576  2.94904084]
# z2:  [1.30213725 3.20907593]
# a2:  [1.30213725 3.20907593]
# z2:  [0.91258506 3.66778965]
# a2:  [0.91258506 3.66778965]
# z2:  [1.15821637 4.0878464 ]
# a2:  [1.15821637 4.0878464 ]
# z2:  [-4.29126722  6.59570552]
# a2:  [-0.04291267  6.59570552]
# z2:  [1.33417706 2.33100296]
# a2:  [1.33417706 2.33100296]
# z2:  [0.82020644 2.25737629]
# a2:  [0.82020644 2.25737629]
# z2:  [1.61968269 2.9818545 ]
# a2:  [1.61968269 2.9818545 ]
# z2:  [1.55113008 2.96633448]
# a2:  [1.55113008 2.96633448]
# z2:  [1.61559981 2.81108032]
# a2:  [1.61559981 2.81108032]
# z2:  [1.33031215 2.75558316]
# a2:  [1.33031215 2.75558316]
# z2:  [1.66453635 2.88193619]
# a2:  [1.66453635 2.88193619]
# z2:  [4.71899033 3.9422751 ]
# a2:  [4.71899033 3.9422751 ]
# z2:  [2.74039236 2.28934154]
# a2:  [2.74039236 2.28934154]
# z2:  [2.85645603 2.38630188]
# a2:  [2.85645603 2.38630188]
# z2:  [-5.46374324 -1.95864582]
# a2:  [-0.05463743 -0.01958646]
# z2:  [-5.75460227 -2.08297558]
# a2:  [-0.05754602 -0.02082976]
# z2:  [2.38137978 2.05959079]
# a2:  [2.38137978 2.05959079]
# z2:  [1.19208859 1.49825013]
# a2:  [1.19208859 1.49825013]
# z2:  [1.32660695 1.81249506]
# a2:  [1.32660695 1.81249506]
# z2:  [2.27492717 2.43281396]
# a2:  [2.27492717 2.43281396]
# z2:  [1.6366233  2.42687073]
# a2:  [1.6366233  2.42687073]
# z2:  [2.0308088  2.95068664]
# a2:  [2.0308088  2.95068664]
# z2:  [-0.83270028  1.64850382]
# a2:  [-0.008327    1.64850382]
# z2:  [1.15180146 3.69350217]
# a2:  [1.15180146 3.69350217]
# z2:  [-6.80436209  2.93995792]
# a2:  [-0.06804362  2.93995792]
# z2:  [-6.88966142  7.53785762]
# a2:  [-0.06889661  7.53785762]
# z2:  [ 2.60040357 -1.67083   ]
# a2:  [ 2.60040357 -0.0167083 ]
# z2:  [ 4.8893406  -3.19021197]
# a2:  [ 4.8893406  -0.03190212]
# z2:  [ 6.03630223 -1.55419847]
# a2:  [ 6.03630223 -0.01554198]
# z2:  [ 5.43002476 -5.55514113]
# a2:  [ 5.43002476 -0.05555141]
# z2:  [7.10549437 0.03139653]
# a2:  [7.10549437 0.03139653]
# z2:  [11.58849256  2.44340856]
# a2:  [11.58849256  2.44340856]
# z2:  [6.10651184 1.10722973]
# a2:  [6.10651184 1.10722973]
# z2:  [10.54661012  2.94766453]
# a2:  [10.54661012  2.94766453]
# z2:  [  2.85186234 -23.17707168]
# a2:  [ 2.85186234 -0.23177072]
# z2:  [ 1.70421624 -4.2091937 ]
# a2:  [ 1.70421624 -0.04209194]
# z2:  [ 13.44627267 -25.71463138]
# a2:  [13.44627267 -0.25714631]
# z2:  [ -6.01998189 -14.91290666]
# a2:  [-0.06019982 -0.14912907]
# z2:  [ -4.16603629 -10.15571566]
# a2:  [-0.04166036 -0.10155716]
# z2:  [ -6.42053186 -15.92756149]
# a2:  [-0.06420532 -0.15927561]
# z2:  [-3.1701667 -7.5973931]
# a2:  [-0.03170167 -0.07597393]
# z2:  [0.88951105 1.93878476]
# a2:  [0.88951105 1.93878476]
# z2:  [0.99992307 2.1477354 ]
# a2:  [0.99992307 2.1477354 ]
# z2:  [1.06584777 2.23356501]
# a2:  [1.06584777 2.23356501]
# z2:  [1.10712016 2.25693268]
# a2:  [1.10712016 2.25693268]
# z2:  [1.52614831 3.18240751]
# a2:  [1.52614831 3.18240751]
# z2:  [1.85610994 3.93776428]
# a2:  [1.85610994 3.93776428]
# z2:  [1.73695655 3.57223266]
# a2:  [1.73695655 3.57223266]
# z2:  [2.80140201 5.74941556]
# a2:  [2.80140201 5.74941556]
# z2:  [2.96382674 6.04173961]
# a2:  [2.96382674 6.04173961]
# z2:  [3.26185618 6.69158736]
# a2:  [3.26185618 6.69158736]
# z2:  [2.9625647  5.99237944]
# a2:  [2.9625647  5.99237944]
# z2:  [3.26550204 6.69597892]
# a2:  [3.26550204 6.69597892]
# z2:  [2.62161966 5.19455804]
# a2:  [2.62161966 5.19455804]
# z2:  [2.28168453 4.38300724]
# a2:  [2.28168453 4.38300724]
# z2:  [2.76238268 5.52513827]
# a2:  [2.76238268 5.52513827]
# z2:  [2.55505273 5.4981221 ]
# a2:  [2.55505273 5.4981221 ]
# z2:  [1.44622316 2.85700898]
# a2:  [1.44622316 2.85700898]
# z2:  [2.74050065 5.91681704]
# a2:  [2.74050065 5.91681704]
# z2:  [1.08316481 1.90469787]
# a2:  [1.08316481 1.90469787]
# z2:  [2.45108325 4.92292417]
# a2:  [2.45108325 4.92292417]
# z2:  [2.23998338 4.52491188]
# a2:  [2.23998338 4.52491188]
# z2:  [2.81483933 5.74374154]
# a2:  [2.81483933 5.74374154]
# z2:  [1.1670428  1.86383472]
# a2:  [1.1670428  1.86383472]
# z2:  [2.28681425 4.64665739]
# a2:  [2.28681425 4.64665739]
# z2:  [3.79771916 7.91672391]
# a2:  [3.79771916 7.91672391]
# z2:  [ -4.81006356 -11.21822558]
# a2:  [-0.04810064 -0.11218226]
# z2:  [-2.48889287 -5.33772491]
# a2:  [-0.02488893 -0.05337725]
# z2:  [2.03907895 3.95418355]
# a2:  [2.03907895 3.95418355]
# z2:  [1.4956206  2.43147878]
# a2:  [1.4956206  2.43147878]
# z2:  [0.29515442 0.17493649]
# a2:  [0.29515442 0.17493649]
# z2:  [0.543356   0.52453263]
# a2:  [0.543356   0.52453263]
# z2:  [0.89350841 0.59974115]
# a2:  [0.89350841 0.59974115]
# z2:  [1.71113836 0.87872235]
# a2:  [1.71113836 0.87872235]
# z2:  [4.71335841 8.25708371]
# a2:  [4.71335841 8.25708371]
# z2:  [2.48224453 4.26488039]
# a2:  [2.48224453 4.26488039]
# z2:  [2.31819967 3.74867076]
# a2:  [2.31819967 3.74867076]
# z2:  [1.93644495 2.73528577]
# a2:  [1.93644495 2.73528577]
# z2:  [2.97402564 5.14459444]
# a2:  [2.97402564 5.14459444]
# z2:  [2.59820895 4.3399907 ]
# a2:  [2.59820895 4.3399907 ]
# z2:  [2.72566136 4.64375422]
# a2:  [2.72566136 4.64375422]
# z2:  [2.40269294 3.90520965]
# a2:  [2.40269294 3.90520965]
# z2:  [2.19070898 3.31369059]
# a2:  [2.19070898 3.31369059]
# z2:  [ 0.31026224 -1.53892794]
# a2:  [ 0.31026224 -0.01538928]
# z2:  [2.87843382 4.72487598]
# a2:  [2.87843382 4.72487598]
# z2:  [2.70252988 2.19413371]
# a2:  [2.70252988 2.19413371]
# z2:  [2.88123354 2.33732197]
# a2:  [2.88123354 2.33732197]
# z2:  [3.48704789 3.21989759]
# a2:  [3.48704789 3.21989759]
# z2:  [3.11975733 2.60150187]
# a2:  [3.11975733 2.60150187]
# z2:  [3.03305608 3.39482295]
# a2:  [3.03305608 3.39482295]
# z2:  [3.33257128 4.00280679]
# a2:  [3.33257128 4.00280679]
# z2:  [2.87608404 3.1039594 ]
# a2:  [2.87608404 3.1039594 ]
# z2:  [3.40986932 4.19569719]
# a2:  [3.40986932 4.19569719]
# z2:  [2.82643572 2.64265427]
# a2:  [2.82643572 2.64265427]
# z2:  [3.26483032 2.78471062]
# a2:  [3.26483032 2.78471062]
# z2:  [4.30865368 4.17415959]
# a2:  [4.30865368 4.17415959]
# z2:  [3.24842999 1.83628041]
# a2:  [3.24842999 1.83628041]
# z2:  [3.71899568 2.70067805]
# a2:  [3.71899568 2.70067805]
# z2:  [4.38915872 3.47180422]
# a2:  [4.38915872 3.47180422]
# z2:  [3.84260865 2.8471336 ]
# a2:  [3.84260865 2.8471336 ]
# z2:  [3.34348851 2.2571272 ]
# a2:  [3.34348851 2.2571272 ]
# z2:  [4.03872841 3.73831281]
# a2:  [4.03872841 3.73831281]
# z2:  [3.82478669 2.92318716]
# a2:  [3.82478669 2.92318716]
# z2:  [3.22494356 0.62028269]
# a2:  [3.22494356 0.62028269]
# z2:  [4.33832116 3.02947646]
# a2:  [4.33832116 3.02947646]
# z2:  [4.34194385 4.23691674]
# a2:  [4.34194385 4.23691674]
# z2:  [3.75567292 3.80477417]
# a2:  [3.75567292 3.80477417]
# z2:  [3.22188175 1.49920399]
# a2:  [3.22188175 1.49920399]
# z2:  [3.4883985  2.12681954]
# a2:  [3.4883985  2.12681954]
# z2:  [3.78717956 3.10886909]
# a2:  [3.78717956 3.10886909]
# z2:  [3.59314018 3.27035572]
# a2:  [3.59314018 3.27035572]
# z2:  [ 2.07180785 -0.08947748]
# a2:  [ 2.07180785e+00 -8.94774767e-04]
# z2:  [2.40281872 0.18085502]
# a2:  [2.40281872 0.18085502]
# z2:  [2.42369817 2.64363603]
# a2:  [2.42369817 2.64363603]
# z2:  [3.15133056 4.80474449]
# a2:  [3.15133056 4.80474449]
# z2:  [2.8133457  4.35221825]
# a2:  [2.8133457  4.35221825]
# z2:  [2.11972323 2.45523316]
# a2:  [2.11972323 2.45523316]
# z2:  [2.09561826 2.31564554]
# a2:  [2.09561826 2.31564554]
# z2:  [3.18245232 5.05315474]
# a2:  [3.18245232 5.05315474]
# z2:  [3.23958265 5.28828773]
# a2:  [3.23958265 5.28828773]
# z2:  [2.16931914 2.49095059]
# a2:  [2.16931914 2.49095059]
# z2:  [2.75283747 3.86376881]
# a2:  [2.75283747 3.86376881]
# z2:  [3.46247774 5.57011896]
# a2:  [3.46247774 5.57011896]
# z2:  [3.76617323 2.70815572]
# a2:  [3.76617323 2.70815572]
# z2:  [3.52594916 2.76953965]
# a2:  [3.52594916 2.76953965]
# z2:  [2.73149254 0.6921548 ]
# a2:  [2.73149254 0.6921548 ]
# z2:  [ 4.55089684 -1.99555641]
# a2:  [ 4.55089684 -0.01995556]
# z2:  [10.64253929 -2.90757232]
# a2:  [10.64253929 -0.02907572]
# z2:  [-1.23648363 -1.68264535]
# a2:  [-0.01236484 -0.01682645]
# z2:  [-1.20495153 -1.5830335 ]
# a2:  [-0.01204952 -0.01583034]
# z2:  [-1.45836448 -2.21581735]
# a2:  [-0.01458364 -0.02215817]
# z2:  [-1.56656314 -2.46584755]
# a2:  [-0.01566563 -0.02465848]
# z2:  [-1.25095433 -1.61616886]
# a2:  [-0.01250954 -0.01616169]
# z2:  [-1.56081436 -2.39718175]
# a2:  [-0.01560814 -0.02397182]
# z2:  [-1.34357153 -1.81170382]
# a2:  [-0.01343572 -0.01811704]
# z2:  [-1.79707805 -2.97155655]
# a2:  [-0.01797078 -0.02971557]
# z2:  [-1.79248458 -2.94066416]
# a2:  [-0.01792485 -0.02940664]
# z2:  [-1.5249441  -2.21225119]
# a2:  [-0.01524944 -0.02212251]
# z2:  [3.47335513 4.89699619]
# a2:  [3.47335513 4.89699619]
# z2:  [2.90314213 3.92482248]
# a2:  [2.90314213 3.92482248]
# z2:  [3.18890689 4.85134321]
# a2:  [3.18890689 4.85134321]
# z2:  [3.03234975 4.5025771 ]
# a2:  [3.03234975 4.5025771 ]
# z2:  [2.79342052 3.90138075]
# a2:  [2.79342052 3.90138075]
# z2:  [2.58849711 3.99188199]
# a2:  [2.58849711 3.99188199]
# z2:  [2.77448504 4.27870552]
# a2:  [2.77448504 4.27870552]
# z2:  [2.47310483 3.38777385]
# a2:  [2.47310483 3.38777385]
# z2:  [2.87349758 4.20909814]
# a2:  [2.87349758 4.20909814]
# z2:  [3.1337196  4.79650401]
# a2:  [3.1337196  4.79650401]
# z2:  [0.74085961 1.4090503 ]
# a2:  [0.74085961 1.4090503 ]
# z2:  [0.5952866  0.78515498]
# a2:  [0.5952866  0.78515498]
# z2:  [1.35485984 2.12285148]
# a2:  [1.35485984 2.12285148]
# z2:  [0.98472179 0.7175631 ]
# a2:  [0.98472179 0.7175631 ]
# z2:  [2.28960539 3.13068682]
# a2:  [2.28960539 3.13068682]
# z2:  [4.30992635 5.97662276]
# a2:  [4.30992635 5.97662276]
# z2:  [2.20728563 3.0608675 ]
# a2:  [2.20728563 3.0608675 ]
# z2:  [ 0.69065674 -2.25965522]
# a2:  [ 0.69065674 -0.02259655]
# z2:  [2.74289382 4.01714561]
# a2:  [2.74289382 4.01714561]
# z2:  [2.42931492 3.557889  ]
# a2:  [2.42931492 3.557889  ]
# z2:  [ 1.04514122 -0.03706329]
# a2:  [ 1.04514122e+00 -3.70632922e-04]
# z2:  [3.92493756 5.75845084]
# a2:  [3.92493756 5.75845084]
# z2:  [3.52755834 5.17543807]
# a2:  [3.52755834 5.17543807]
# z2:  [3.83847397 5.63159626]
# a2:  [3.83847397 5.63159626]
# z2:  [1.81860597 2.42604833]
# a2:  [1.81860597 2.42604833]
# z2:  [1.91954905 2.56070795]
# a2:  [1.91954905 2.56070795]
# z2:  [1.92276016 2.56499162]
# a2:  [1.92276016 2.56499162]
# z2:  [1.97625387 2.35790064]
# a2:  [1.97625387 2.35790064]
# z2:  [2.33995665 3.09660956]
# a2:  [2.33995665 3.09660956]
# z2:  [ 0.27878073 -1.79839183]
# a2:  [ 0.27878073 -0.01798392]
# z2:  [ 0.51085646 -1.37020177]
# a2:  [ 0.51085646 -0.01370202]
# z2:  [1.61105994 1.12528356]
# a2:  [1.61105994 1.12528356]
# z2:  [2.54908488 2.89158217]
# a2:  [2.54908488 2.89158217]
# z2:  [1.85276813 1.15258756]
# a2:  [1.85276813 1.15258756]
# z2:  [2.36747032 2.16342686]
# a2:  [2.36747032 2.16342686]
# z2:  [3.43887439 4.42660577]
# a2:  [3.43887439 4.42660577]
# z2:  [3.53276906 4.52487132]
# a2:  [3.53276906 4.52487132]
# z2:  [3.47519499 4.70219424]
# a2:  [3.47519499 4.70219424]
# z2:  [3.49548473 4.72964776]
# a2:  [3.49548473 4.72964776]
# z2:  [3.30724482 4.47494532]
# a2:  [3.30724482 4.47494532]
# z2:  [3.00184862 4.01710075]
# a2:  [3.00184862 4.01710075]
# z2:  [ 0.9468204  -1.85735066]
# a2:  [ 0.9468204  -0.01857351]
# z2:  [2.83349576 3.82017997]
# a2:  [2.83349576 3.82017997]
# z2:  [2.73337895 3.64425671]
# a2:  [2.73337895 3.64425671]
# z2:  [2.49910891 3.13162404]
# a2:  [2.49910891 3.13162404]
# z2:  [2.58863115 3.40918654]
# a2:  [2.58863115 3.40918654]
# z2:  [2.66291877 3.5577228 ]
# a2:  [2.66291877 3.5577228 ]
# z2:  [2.26096237 2.62764993]
# a2:  [2.26096237 2.62764993]
# z2:  [2.44889597 3.31216386]
# a2:  [2.44889597 3.31216386]
# z2:  [2.36576597 3.08455855]
# a2:  [2.36576597 3.08455855]
# z2:  [2.48044012 3.30541059]
# a2:  [2.48044012 3.30541059]
# z2:  [2.70424743 4.0488933 ]
# a2:  [2.70424743 4.0488933 ]
# z2:  [2.76366428 4.13785428]
# a2:  [2.76366428 4.13785428]
# z2:  [2.77149354 4.14957652]
# a2:  [2.77149354 4.14957652]
# z2:  [2.44806904 3.30348604]
# a2:  [2.44806904 3.30348604]
# z2:  [2.58194163 3.87763   ]
# a2:  [2.58194163 3.87763   ]
# z2:  [2.60697498 3.7136774 ]
# a2:  [2.60697498 3.7136774 ]
# z2:  [2.83411716 4.24816874]
# a2:  [2.83411716 4.24816874]
# z2:  [2.80791939 4.20889989]
# a2:  [2.80791939 4.20889989]
# z2:  [1.73895274 0.87423422]
# a2:  [1.73895274 0.87423422]
# z2:  [1.5186467 0.0386517]
# a2:  [1.5186467 0.0386517]
# z2:  [ 1.39785009 -0.74989659]
# a2:  [ 1.39785009 -0.00749897]
# z2:  [2.42127878 2.28462324]
# a2:  [2.42127878 2.28462324]
# z2:  [ 1.16161816 -1.58020671]
# a2:  [ 1.16161816 -0.01580207]
# z2:  [2.6665998  3.59009126]
# a2:  [2.6665998  3.59009126]
# z2:  [2.64320186 3.53680185]
# a2:  [2.64320186 3.53680185]
# z2:  [2.83401421 4.3214795 ]
# a2:  [2.83401421 4.3214795 ]
# z2:  [2.71081267 4.13361419]
# a2:  [2.71081267 4.13361419]
# z2:  [2.49079643 3.66453459]
# a2:  [2.49079643 3.66453459]
# z2:  [2.42884557 3.6608518 ]
# a2:  [2.42884557 3.6608518 ]
# z2:  [2.47277627 3.77611534]
# a2:  [2.47277627 3.77611534]
# z2:  [2.40179645 3.66772382]
# a2:  [2.40179645 3.66772382]
# z2:  [2.20732523 1.45348919]
# a2:  [2.20732523 1.45348919]
# z2:  [2.70726239 1.49494454]
# a2:  [2.70726239 1.49494454]
# z2:  [2.61885874 2.75541423]
# a2:  [2.61885874 2.75541423]
# z2:  [2.39035719 1.81054021]
# a2:  [2.39035719 1.81054021]
# z2:  [2.41304197 2.09336112]
# a2:  [2.41304197 2.09336112]
# z2:  [ 1.54057867 -0.46118019]
# a2:  [ 1.54057867 -0.0046118 ]
# z2:  [2.72935026 2.56558897]
# a2:  [2.72935026 2.56558897]
# z2:  [2.83393299 2.16407255]
# a2:  [2.83393299 2.16407255]
# z2:  [2.45262904 2.83553658]
# a2:  [2.45262904 2.83553658]
# z2:  [2.88754521 3.86457597]
# a2:  [2.88754521 3.86457597]
# z2:  [1.99080991 0.23031532]
# a2:  [1.99080991 0.23031532]
# z2:  [2.91692986 2.79323724]
# a2:  [2.91692986 2.79323724]
# z2:  [2.66863544 1.36469738]
# a2:  [2.66863544 1.36469738]
# z2:  [1.91985648 2.57141901]
# a2:  [1.91985648 2.57141901]
# z2:  [1.46022371 1.49456428]
# a2:  [1.46022371 1.49456428]
# z2:  [2.03004674 1.42684315]
# a2:  [2.03004674 1.42684315]
# z2:  [2.45864036 2.97487744]
# a2:  [2.45864036 2.97487744]
# z2:  [2.56003652 3.39604233]
# a2:  [2.56003652 3.39604233]
# z2:  [2.35500558 2.80179185]
# a2:  [2.35500558 2.80179185]
# z2:  [1.78990575 0.9370547 ]
# a2:  [1.78990575 0.9370547 ]
# z2:  [ 1.14125876 -1.74615354]
# a2:  [ 1.14125876 -0.01746154]
# z2:  [2.31855433 1.77737151]
# a2:  [2.31855433 1.77737151]
# z2:  [ 1.31712308 -1.48350435]
# a2:  [ 1.31712308 -0.01483504]
# z2:  [ 1.38931027 -1.30711035]
# a2:  [ 1.38931027 -0.0130711 ]
# z2:  [ 1.55847012 -1.29110831]
# a2:  [ 1.55847012 -0.01291108]
# z2:  [ 0.67177742 -5.8178932 ]
# a2:  [ 0.67177742 -0.05817893]
# z2:  [ -4.71053441 -27.45936722]
# a2:  [-0.04710534 -0.27459367]
# z2:  [2.65456214 1.06239747]
# a2:  [2.65456214 1.06239747]
# z2:  [3.96911229 1.56782503]
# a2:  [3.96911229 1.56782503]
# z2:  [5.83242603 4.1258806 ]
# a2:  [5.83242603 4.1258806 ]
# z2:  [5.47220997 1.2690843 ]
# a2:  [5.47220997 1.2690843 ]
# z2:  [ 5.94638928 -0.70485975]
# a2:  [ 5.94638928 -0.0070486 ]
# z2:  [7.74622655 5.16905342]
# a2:  [7.74622655 5.16905342]
# z2:  [-0.07246471 -0.04835567]
# a2:  [-0.00072465 -0.00048356]
# z2:  [-0.07247735 -0.04836411]
# a2:  [-0.00072477 -0.00048364]
# z2:  [ 0.58115696 -3.26272824]
# a2:  [ 0.58115696 -0.03262728]
# z2:  [-0.07330525 -0.0483389 ]
# a2:  [-0.00073305 -0.00048339]
# z2:  [-0.07331056 -0.04834241]
# a2:  [-0.00073311 -0.00048342]
# z2:  [-0.01235965 -0.34814621]
# a2:  [-0.0001236  -0.00348146]
# z2:  [-0.07330652 -0.04816212]
# a2:  [-0.00073307 -0.00048162]
# z2:  [-0.07327087 -0.0481387 ]
# a2:  [-0.00073271 -0.00048139]
# z2:  [-0.07324266 -0.04812016]
# a2:  [-0.00073243 -0.0004812 ]
# z2:  [-0.0732204  -0.04810554]
# a2:  [-0.0007322  -0.00048106]
# z2:  [  2.06916721 -10.58588146]
# a2:  [ 2.06916721 -0.10585881]
# z2:  [-0.2199428  -0.04059365]
# a2:  [-0.00219943 -0.00040594]
# z2:  [-0.21970489 -0.04054974]
# a2:  [-0.00219705 -0.0004055 ]
# z2:  [-0.21961005 -0.04053223]
# a2:  [-0.0021961  -0.00040532]
# z2:  [ 0.04471968 -2.30545934]
# a2:  [ 0.04471968 -0.02305459]
# z2:  [-0.22133737 -0.03948349]
# a2:  [-0.00221337 -0.00039483]
# z2:  [-0.19409652 -0.27276689]
# a2:  [-0.00194097 -0.00272767]
# z2:  [-0.01748762 -1.78881271]
# a2:  [-0.00017488 -0.01788813]
# z2:  [-0.22141338 -0.04293943]
# a2:  [-0.00221413 -0.00042939]
# z2:  [-0.22128274 -0.04291409]
# a2:  [-0.00221283 -0.00042914]
# z2:  [-0.22132938 -0.04292314]
# a2:  [-0.00221329 -0.00042923]
# z2:  [-0.16716445 -0.50762332]
# a2:  [-0.00167164 -0.00507623]
# z2:  [-0.22134023 -0.04295893]
# a2:  [-0.0022134  -0.00042959]
# z2:  [-0.1794966  -0.40187152]
# a2:  [-0.00179497 -0.00401872]
# z2:  [-0.22118598 -0.04263347]
# a2:  [-0.00221186 -0.00042633]
# z2:  [ 0.42568311 -5.59072203]
# a2:  [ 0.42568311 -0.05590722]

# %%
# predict example in given set
def predict(j, pred_set):
    # z for second layer and activation (ReLu)
    z2 = np.dot(weights, np.transpose(pred_set[j, :]))
    #print('z2', z2)
    a2 = np.where(z2 > 0, z2, z2 * .01)
    #print('a2', a2)
    # add bias unit for second layer
    a2_bias = np.concatenate((np.ones(1), a2))
    # z for third layer, no final activation for now
    z3 = np.dot(weights2, a2_bias)

    # calculate error
    sq_error =  np.square(z3 - house_sk_target[j])
    print(f'Prediction: {z3}, actual: {house_sk_target[j]}, error: {sq_error}')
    return sq_error

# %%
tot_err = 0
# Predict CV example and see average error
for j in range(0, m_cv):
    global tot_err
    tot_err += predict(j, house_sk_cv_bias)

print('Average squared CV error ($): ', tot_err/m_cv)
# Out:
# Prediction: [13.04132294], actual: 24.0, error: [120.09260295]
# Prediction: [13.04132294], actual: 21.6, error: [73.25095305]
# Prediction: [13.33330752], actual: 34.7, error: [456.53554753]
# Prediction: [13.04132294], actual: 33.4, error: [414.47573171]
# Prediction: [13.98848216], actual: 36.2, error: [493.35152477]
# Prediction: [13.20887349], actual: 28.7, error: [239.97500042]
# Prediction: [13.41602946], actual: 22.9, error: [89.94569715]
# Prediction: [13.9515452], actual: 27.1, error: [172.8818637]
# Prediction: [14.19662124], actual: 16.5, error: [5.30555371]
# Prediction: [14.9914704], actual: 18.9, error: [15.27660364]
# Prediction: [15.78824906], actual: 15.0, error: [0.62133658]
# Prediction: [15.64197464], actual: 18.9, error: [10.61472928]
# Prediction: [15.67019275], actual: 21.7, error: [36.35857544]
# Prediction: [14.84898243], actual: 20.4, error: [30.81379606]
# Prediction: [15.40207556], actual: 18.2, error: [7.82838117]
# Prediction: [15.67713459], actual: 19.9, error: [17.83259227]
# Prediction: [15.70273825], actual: 23.1, error: [54.71948141]
# Prediction: [15.2258701], actual: 17.5, error: [5.17166682]
# Prediction: [15.7258176], actual: 20.2, error: [20.01830812]
# Prediction: [15.58157164], actual: 18.2, error: [6.8561671]
# Prediction: [14.13889846], actual: 13.6, error: [0.29041155]
# Prediction: [14.12162376], actual: 19.6, error: [30.01260624]
# Prediction: [14.48575305], actual: 15.2, error: [0.5101487]
# Prediction: [15.78860968], actual: 14.5, error: [1.6605149]
# Prediction: [15.78351599], actual: 15.6, error: [0.03367812]
# Prediction: [15.76535001], actual: 13.9, error: [3.47953068]
# Prediction: [15.68885457], actual: 16.6, error: [0.83018599]
# Prediction: [15.71513439], actual: 14.8, error: [0.83747095]
# Prediction: [15.36394053], actual: 18.4, error: [9.21765709]
# Prediction: [15.52626232], actual: 21.0, error: [29.96180415]
# Prediction: [15.42380261], actual: 12.7, error: [7.41910066]
# Prediction: [15.43335891], actual: 14.5, error: [0.87115885]
# Prediction: [15.35844116], actual: 13.2, error: [4.65886822]
# Prediction: [15.34834394], actual: 13.1, error: [5.05505046]
# Prediction: [15.34636056], actual: 13.5, error: [3.4090473]
# Prediction: [15.30479969], actual: 18.9, error: [12.92546529]
# Prediction: [15.67605274], actual: 20.0, error: [18.69651986]
# Prediction: [15.75795741], actual: 21.0, error: [27.47901053]
# Prediction: [15.48916406], actual: 24.7, error: [84.83949865]
# Prediction: [13.04132294], actual: 30.8, error: [315.37061099]
# Prediction: [13.11786531], actual: 34.9, error: [474.46139153]
# Prediction: [13.19496947], actual: 26.6, error: [179.6948436]
# Prediction: [13.05831675], actual: 25.3, error: [149.8588088]
# Prediction: [13.18415522], actual: 24.7, error: [132.61468093]
# Prediction: [14.71578029], actual: 21.2, error: [42.04510518]
# Prediction: [15.60586807], actual: 19.3, error: [13.64661074]
# Prediction: [14.14929137], actual: 20.0, error: [34.23079148]
# Prediction: [13.15901562], actual: 16.6, error: [11.84037352]
# Prediction: [13.04132294], actual: 14.4, error: [1.84600336]
# Prediction: [14.34310509], actual: 19.4, error: [25.57218614]
# Prediction: [15.79852659], actual: 19.7, error: [15.2214948]
# Prediction: [13.62571344], actual: 20.5, error: [47.25581576]
# Prediction: [13.20718816], actual: 25.0, error: [139.07041115]
# Prediction: [13.33667819], actual: 23.4, error: [101.27044578]
# Prediction: [15.7698577], actual: 18.9, error: [9.79779081]
# Prediction: [15.57043765], actual: 35.4, error: [393.21154296]
# Prediction: [15.75272849], actual: 24.7, error: [80.05366744]
# Prediction: [15.78419214], actual: 31.6, error: [250.13977815]
# Prediction: [14.57293171], actual: 23.3, error: [76.16172093]
# Prediction: [13.04132294], actual: 19.6, error: [43.0162448]
# Prediction: [14.64947223], actual: 18.7, error: [16.40677524]
# Prediction: [13.1181462], actual: 16.0, error: [8.30508131]
# Prediction: [13.04132294], actual: 22.2, error: [83.88136553]
# Prediction: [13.08457991], actual: 25.0, error: [141.97723585]
# Prediction: [13.04132294], actual: 33.0, error: [398.34879006]
# Prediction: [13.91910247], actual: 23.5, error: [91.79359756]
# Prediction: [15.70075487], actual: 19.4, error: [13.68441456]
# Prediction: [13.96278078], actual: 22.0, error: [64.59689287]
# Prediction: [13.43681528], actual: 17.4, error: [15.70683311]
# Prediction: [13.04132294], actual: 20.9, error: [61.75880516]
# Prediction: [13.04132294], actual: 24.2, error: [124.51607377]
# Prediction: [13.06337276], actual: 21.7, error: [74.59133009]
# Prediction: [13.09089993], actual: 22.8, error: [94.26662425]
# Prediction: [13.35339112], actual: 23.4, error: [100.93435007]
# Prediction: [13.66377396], actual: 24.1, error: [108.91481403]
# Prediction: [14.36346957], actual: 21.4, error: [49.51276044]
# Prediction: [13.05101362], actual: 20.0, error: [48.28841165]
# Prediction: [13.70731182], actual: 20.8, error: [50.3062256]
# Prediction: [13.28288786], actual: 21.2, error: [62.68066457]
# Prediction: [13.23204687], actual: 20.3, error: [49.95596139]
# Prediction: [13.04132294], actual: 28.0, error: [223.76201945]
# Prediction: [13.09511327], actual: 23.9, error: [116.7455773]
# Prediction: [13.06407498], actual: 24.8, error: [137.731936]
# Prediction: [13.09721994], actual: 22.9, error: [96.09449694]
# Prediction: [13.40886678], actual: 23.9, error: [110.0638762]
# Prediction: [13.15761117], actual: 26.6, error: [180.69781746]
# Prediction: [13.10059061], actual: 22.5, error: [88.34889685]
# Prediction: [13.16322896], actual: 22.2, error: [81.66323085]
# Prediction: [13.70878977], actual: 23.6, error: [97.83603989]
# Prediction: [14.42561964], actual: 28.7, error: [203.75793467]
# Prediction: [14.78543902], actual: 22.6, error: [61.06736325]
# Prediction: [13.77873124], actual: 22.0, error: [67.58926004]
# Prediction: [13.68336927], actual: 22.9, error: [84.94628199]
# Prediction: [19.46178627], actual: 25.0, error: [30.67181132]
# Prediction: [19.46178627], actual: 20.6, error: [1.2955305]
# Prediction: [19.51248682], actual: 28.4, error: [78.98789061]
# Prediction: [19.46178627], actual: 21.4, error: [3.75667246]
# Prediction: [19.46178627], actual: 38.7, error: [370.10886753]
# Prediction: [19.46178627], actual: 43.8, error: [592.34864758]
# Prediction: [19.47765652], actual: 33.2, error: [188.30271048]
# Prediction: [19.46178627], actual: 27.5, error: [64.61287997]
# Prediction: [12.51148826], actual: 26.5, error: [195.67846066]
# Prediction: [12.51079868], actual: 18.6, error: [37.07837274]
# Prediction: [12.51079868], actual: 19.3, error: [46.09325459]
# Prediction: [12.51128321], actual: 20.1, error: [57.58862248]
# Prediction: [12.51079868], actual: 19.5, error: [48.84893512]
# Average squared CV error ($):  [94.11885428]

# %%
tot_err = 0
# Predict in training example and see average error
for j in range(0, m_train):
    global tot_err
    tot_err += predict(j, house_sk_train_bias)

print('Average squared training error ($): ', tot_err/m_train)
# Out:
# Prediction: [16.72764487], actual: 24.0, error: [52.88714913]
# Prediction: [14.38993411], actual: 21.6, error: [51.9850501]
# Prediction: [14.60689403], actual: 34.7, error: [403.7329074]
# Prediction: [13.66936537], actual: 33.4, error: [389.29794291]
# Prediction: [13.54835824], actual: 36.2, error: [513.09687443]
# Prediction: [13.69655199], actual: 28.7, error: [225.10345207]
# Prediction: [16.89045254], actual: 22.9, error: [36.1146607]
# Prediction: [16.8211533], actual: 27.1, error: [105.65468947]
# Prediction: [17.36861728], actual: 16.5, error: [0.75449597]
# Prediction: [17.36435271], actual: 18.9, error: [2.3582126]
# Prediction: [17.05463842], actual: 15.0, error: [4.22153905]
# Prediction: [16.8211533], actual: 18.9, error: [4.3216036]
# Prediction: [17.16231878], actual: 21.7, error: [20.59055088]
# Prediction: [12.5457258], actual: 20.4, error: [61.68962323]
# Prediction: [12.55472404], actual: 18.2, error: [31.86914069]
# Prediction: [12.54640813], actual: 19.9, error: [54.0753134]
# Prediction: [12.55108316], actual: 23.1, error: [111.27964644]
# Prediction: [12.55113647], actual: 17.5, error: [24.49125024]
# Prediction: [13.06881343], actual: 20.2, error: [50.85382193]
# Prediction: [12.54889757], actual: 18.2, error: [31.93495866]
# Prediction: [12.55656313], actual: 13.6, error: [1.08876049]
# Prediction: [12.54805532], actual: 19.6, error: [49.72992378]
# Prediction: [12.5457258], actual: 15.2, error: [7.04517154]
# Prediction: [12.54698385], actual: 14.5, error: [3.8142721]
# Prediction: [12.54709579], actual: 15.6, error: [9.32022411]
# Prediction: [12.82192558], actual: 13.9, error: [1.16224445]
# Prediction: [12.55639788], actual: 16.6, error: [16.35071809]
# Prediction: [12.77128192], actual: 14.8, error: [4.11569703]
# Prediction: [12.55050212], actual: 18.4, error: [34.2166255]
# Prediction: [12.55461209], actual: 21.0, error: [71.3245769]
# Prediction: [12.5653055], actual: 12.7, error: [0.01814261]
# Prediction: [12.55647784], actual: 14.5, error: [3.77727838]
# Prediction: [14.03360937], actual: 13.2, error: [0.69490459]
# Prediction: [12.5660518], actual: 13.1, error: [0.28510068]
# Prediction: [13.76482157], actual: 13.5, error: [0.07013046]
# Prediction: [13.08081609], actual: 18.9, error: [33.8629014]
# Prediction: [13.59861007], actual: 20.0, error: [40.97779304]
# Prediction: [13.08081609], actual: 21.0, error: [62.71347383]
# Prediction: [13.26579175], actual: 24.7, error: [130.74111841]
# Prediction: [13.99009199], actual: 30.8, error: [282.57300746]
# Prediction: [13.99062506], actual: 34.9, error: [437.20196053]
# Prediction: [14.90892433], actual: 26.6, error: [136.68125038]
# Prediction: [14.97627294], actual: 25.3, error: [106.57934046]
# Prediction: [14.42649502], actual: 24.7, error: [105.54490457]
# Prediction: [14.69676205], actual: 21.2, error: [42.29210388]
# Prediction: [14.29642568], actual: 19.3, error: [25.03575595]
# Prediction: [14.29642568], actual: 20.0, error: [32.53076]
# Prediction: [14.51818324], actual: 16.6, error: [4.33396101]
# Prediction: [14.29642568], actual: 14.4, error: [0.01072764]
# Prediction: [14.29642568], actual: 19.4, error: [26.04647082]
# Prediction: [15.39644994], actual: 19.7, error: [18.52054314]
# Prediction: [15.48120824], actual: 20.5, error: [25.18827078]
# Prediction: [15.32501842], actual: 25.0, error: [93.60526866]
# Prediction: [15.32501842], actual: 23.4, error: [65.20532759]
# Prediction: [12.54479071], actual: 18.9, error: [40.38868506]
# Prediction: [14.34813357], actual: 35.4, error: [443.18107998]
# Prediction: [14.85747626], actual: 24.7, error: [96.87527349]
# Prediction: [17.12789015], actual: 31.6, error: [209.4419634]
# Prediction: [12.80603233], actual: 23.3, error: [110.12335748]
# Prediction: [12.61327394], actual: 19.6, error: [48.81434108]
# Prediction: [12.70869366], actual: 18.7, error: [35.89575171]
# Prediction: [13.02161007], actual: 16.0, error: [8.87080656]
# Prediction: [12.61327394], actual: 22.2, error: [91.90531661]
# Prediction: [12.68363932], actual: 25.0, error: [151.69274049]
# Prediction: [13.83697068], actual: 33.0, error: [367.22169283]
# Prediction: [15.97957743], actual: 23.5, error: [56.55675566]
# Prediction: [15.97957743], actual: 19.4, error: [11.69929057]
# Prediction: [13.39812328], actual: 22.0, error: [73.99228307]
# Prediction: [13.36134138], actual: 17.4, error: [16.31076346]
# Prediction: [13.36134138], actual: 20.9, error: [56.8313738]
# Prediction: [13.49304541], actual: 24.2, error: [114.63887653]
# Prediction: [13.60921786], actual: 21.7, error: [65.46075558]
# Prediction: [13.37020032], actual: 22.8, error: [88.92112204]
# Prediction: [13.60528271], actual: 23.4, error: [95.93648671]
# Prediction: [13.65390631], actual: 24.1, error: [109.1208734]
# Prediction: [14.06970322], actual: 21.4, error: [53.73325082]
# Prediction: [14.23343965], actual: 20.0, error: [33.25321824]
# Prediction: [14.00588537], actual: 20.8, error: [46.15999363]
# Prediction: [14.0154666], actual: 21.2, error: [51.61752015]
# Prediction: [13.59313621], actual: 20.3, error: [44.98202192]
# Prediction: [13.26783295], actual: 28.0, error: [217.03674602]
# Prediction: [13.33553297], actual: 23.9, error: [111.60796356]
# Prediction: [13.26783295], actual: 24.8, error: [132.99087689]
# Prediction: [13.60153543], actual: 22.9, error: [86.46144334]
# Prediction: [13.7353751], actual: 23.9, error: [103.31959935]
# Prediction: [13.98058779], actual: 26.6, error: [159.2495646]
# Prediction: [13.78388457], actual: 22.5, error: [75.97066825]
# Prediction: [13.82866254], actual: 22.2, error: [70.07929094]
# Prediction: [14.38993411], actual: 23.6, error: [84.82531365]
# Prediction: [14.43471208], actual: 28.7, error: [203.4984394]
# Prediction: [14.64154365], actual: 22.6, error: [63.33702745]
# Prediction: [14.56851292], actual: 22.0, error: [55.22700027]
# Prediction: [14.11665082], actual: 22.9, error: [77.1472228]
# Prediction: [14.04628544], actual: 25.0, error: [119.98386263]
# Prediction: [14.01590039], actual: 20.6, error: [43.35036766]
# Prediction: [15.29705857], actual: 28.4, error: [171.68707409]
# Prediction: [14.47318428], actual: 21.4, error: [47.98077604]
# Prediction: [14.20291725], actual: 38.7, error: [600.10706316]
# Prediction: [14.3825622], actual: 43.8, error: [865.38564681]
# Prediction: [14.20291725], actual: 33.2, error: [360.88915294]
# Prediction: [12.54780166], actual: 27.5, error: [223.56823535]
# Prediction: [12.54736454], actual: 26.5, error: [194.67603637]
# Prediction: [16.91552197], actual: 18.6, error: [2.83746624]
# Prediction: [12.54795625], actual: 19.3, error: [45.59009486]
# Prediction: [12.54890511], actual: 20.1, error: [57.01903401]
# Prediction: [12.54818014], actual: 19.5, error: [48.32779943]
# Prediction: [12.54731656], actual: 19.5, error: [48.33980701]
# Prediction: [12.55157047], actual: 20.4, error: [61.59784613]
# Prediction: [12.54754578], actual: 19.8, error: [52.5980922]
# Prediction: [12.5496834], actual: 19.4, error: [46.92683758]
# Prediction: [12.54847866], actual: 21.7, error: [83.75034292]
# Prediction: [14.45976642], actual: 22.8, error: [69.55949615]
# Prediction: [14.49388297], actual: 18.8, error: [18.54264389]
# Prediction: [14.38993411], actual: 18.7, error: [18.57666795]
# Prediction: [14.8249201], actual: 18.5, error: [13.5062123]
# Prediction: [15.74791896], actual: 18.3, error: [6.51311763]
# Prediction: [14.58183969], actual: 21.2, error: [43.80004585]
# Prediction: [14.5173381], actual: 19.2, error: [21.92732251]
# Prediction: [15.85536565], actual: 20.4, error: [20.65370141]
# Prediction: [14.67779248], actual: 19.3, error: [21.36480232]
# Prediction: [13.51393339], actual: 22.0, error: [72.01332646]
# Prediction: [13.71034867], actual: 20.3, error: [43.42350466]
# Prediction: [13.70316274], actual: 20.5, error: [46.19699667]
# Prediction: [13.83627345], actual: 17.3, error: [11.99740164]
# Prediction: [13.68109169], actual: 18.8, error: [26.20322229]
# Prediction: [13.58459499], actual: 21.4, error: [61.08055553]
# Prediction: [14.02481842], actual: 15.7, error: [2.80623331]
# Prediction: [12.54640904], actual: 16.2, error: [13.3487269]
# Prediction: [12.54385563], actual: 18.0, error: [29.76951139]
# Prediction: [12.54385563], actual: 14.3, error: [3.08404305]
# Prediction: [12.54484714], actual: 19.2, error: [44.29105956]
# Prediction: [12.54385563], actual: 19.6, error: [49.78917337]
# Prediction: [12.54979404], actual: 23.0, error: [109.20680457]
# Prediction: [12.54823214], actual: 18.4, error: [34.24318705]
# Prediction: [13.29035028], actual: 15.6, error: [5.33448182]
# Prediction: [12.54504438], actual: 18.1, error: [30.85753196]
# Prediction: [12.55379741], actual: 17.4, error: [23.48567959]
# Prediction: [12.54535889], actual: 17.1, error: [20.74475564]
# Prediction: [12.54644636], actual: 13.3, error: [0.5678431]
# Prediction: [12.54385563], actual: 17.8, error: [27.62705364]
# Prediction: [12.54855732], actual: 14.0, error: [2.10668586]
# Prediction: [12.54385563], actual: 14.4, error: [3.44527192]
# Prediction: [17.28869545], actual: 13.4, error: [15.12195232]
# Prediction: [17.28869545], actual: 15.6, error: [2.85169233]
# Prediction: [17.28869545], actual: 11.8, error: [30.12577777]
# Prediction: [22.2129657], actual: 13.8, error: [70.77799193]
# Prediction: [22.27524372], actual: 15.6, error: [44.5588787]
# Prediction: [17.56535933], actual: 14.6, error: [8.79335596]
# Prediction: [19.06347754], actual: 17.8, error: [1.59637549]
# Prediction: [19.15141957], actual: 15.4, error: [14.07314878]
# Prediction: [18.5733967], actual: 21.5, error: [8.56500687]
# Prediction: [19.32679035], actual: 19.6, error: [0.07464351]
# Prediction: [19.29804665], actual: 15.3, error: [15.98437704]
# Prediction: [20.68954965], actual: 19.4, error: [1.66293831]
# Prediction: [19.67890067], actual: 17.0, error: [7.17650877]
# Prediction: [23.66554907], actual: 15.6, error: [65.05308174]
# Prediction: [23.65494127], actual: 13.1, error: [111.40678526]
# Prediction: [18.95329336], actual: 41.3, error: [499.37529775]
# Prediction: [19.11651651], actual: 24.3, error: [26.86850113]
# Prediction: [18.93823713], actual: 23.3, error: [19.02497529]
# Prediction: [19.3726434], actual: 27.0, error: [58.17656877]
# Prediction: [18.48650612], actual: 50.0, error: [993.10029663]
# Prediction: [17.67730425], actual: 50.0, error: [1044.75666035]
# Prediction: [17.7391405], actual: 50.0, error: [1040.76305596]
# Prediction: [17.38411517], actual: 22.7, error: [28.25863151]
# Prediction: [21.06236228], actual: 25.0, error: [15.50499085]
# Prediction: [18.75997157], actual: 50.0, error: [975.93937626]
# Prediction: [21.27708455], actual: 23.8, error: [6.36510236]
# Prediction: [20.08832728], actual: 23.8, error: [13.77651436]
# Prediction: [19.52457438], actual: 22.3, error: [7.70298739]
# Prediction: [20.17045214], actual: 17.4, error: [7.67540505]
# Prediction: [19.21506633], actual: 19.1, error: [0.01324026]
# Prediction: [15.51203528], actual: 23.1, error: [57.57720865]
# Prediction: [15.58666522], actual: 23.6, error: [64.21353423]
# Prediction: [15.70767235], actual: 22.6, error: [47.50418037]
# Prediction: [15.82867948], actual: 29.4, error: [184.18074054]
# Prediction: [15.70767235], actual: 23.2, error: [56.13497355]
# Prediction: [15.58133451], actual: 24.6, error: [81.33632715]
# Prediction: [15.81215428], actual: 29.9, error: [198.46739698]
# Prediction: [14.38993411], actual: 37.2, error: [520.29910579]
# Prediction: [14.46136563], actual: 39.8, error: [642.04639152]
# Prediction: [14.38993411], actual: 36.2, error: [475.67897401]
# Prediction: [14.53812787], actual: 37.9, error: [545.77706958]
# Prediction: [14.38993411], actual: 32.5, error: [327.97448645]
# Prediction: [14.70444604], actual: 26.4, error: [136.78598251]
# Prediction: [14.91181068], actual: 29.6, error: [215.74290556]
# Prediction: [14.61755545], actual: 50.0, error: [1251.91738204]
# Prediction: [16.98267383], actual: 32.0, error: [225.52008527]
# Prediction: [17.57065121], actual: 29.8, error: [149.55697189]
# Prediction: [16.8211533], actual: 34.9, error: [326.84469798]
# Prediction: [17.84571587], actual: 37.0, error: [366.88660041]
# Prediction: [17.20443139], actual: 30.5, error: [176.77214464]
# Prediction: [17.16285185], actual: 36.4, error: [370.06786901]
# Prediction: [16.63529366], actual: 31.1, error: [209.22772943]
# Prediction: [17.52392312], actual: 29.1, error: [134.00555604]
# Prediction: [17.71155072], actual: 50.0, error: [1042.54395721]
# Prediction: [19.25237249], actual: 33.3, error: [197.3358387]
# Prediction: [21.49536376], actual: 30.3, error: [77.52161925]
# Prediction: [19.50291589], actual: 34.6, error: [227.92194876]
# Prediction: [15.13800156], actual: 34.9, error: [390.53658254]
# Prediction: [15.80967109], actual: 32.9, error: [292.07934234]
# Prediction: [17.45554669], actual: 24.1, error: [44.14875975]
# Prediction: [17.36972225], actual: 42.3, error: [621.51874855]
# Prediction: [17.50832073], actual: 48.5, error: [960.48418411]
# Prediction: [17.62719557], actual: 50.0, error: [1047.99846643]
# Prediction: [13.64186667], actual: 22.6, error: [80.24815276]
# Prediction: [13.75008009], actual: 24.4, error: [113.42079399]
# Prediction: [14.04007075], actual: 22.5, error: [71.57040291]
# Prediction: [14.2160027], actual: 24.4, error: [103.713801]
# Prediction: [13.64186667], actual: 20.0, error: [40.42585944]
# Prediction: [13.83643761], actual: 21.7, error: [61.83561352]
# Prediction: [13.73035647], actual: 19.3, error: [31.0209291]
# Prediction: [13.95957702], actual: 22.4, error: [71.24074007]
# Prediction: [14.13918174], actual: 28.1, error: [194.90444642]
# Prediction: [14.77017437], actual: 23.7, error: [79.74178571]
# Prediction: [13.81618091], actual: 25.0, error: [125.07780953]
# Prediction: [15.91761127], actual: 23.3, error: [54.49966335]
# Prediction: [15.91867741], actual: 28.7, error: [163.36220708]
# Prediction: [15.69905214], actual: 21.5, error: [33.65099611]
# Prediction: [15.86750259], actual: 23.0, error: [50.87251929]
# Prediction: [15.04116478], actual: 26.7, error: [135.9284386]
# Prediction: [14.85245763], actual: 21.7, error: [46.88883652]
# Prediction: [15.11099709], actual: 27.5, error: [153.48739305]
# Prediction: [14.76396783], actual: 30.1, error: [235.1938826]
# Prediction: [15.39565704], actual: 44.8, error: [864.61538509]
# Prediction: [15.55824371], actual: 50.0, error: [1186.23457637]
# Prediction: [15.27145148], actual: 37.6, error: [498.56407899]
# Prediction: [15.73754058], actual: 31.6, error: [251.61761892]
# Prediction: [15.64463684], actual: 46.7, error: [964.43558124]
# Prediction: [15.59621739], actual: 31.5, error: [252.93030128]
# Prediction: [15.63026499], actual: 24.3, error: [75.1643052]
# Prediction: [15.66807664], actual: 31.7, error: [257.02256667]
# Prediction: [15.34981293], actual: 41.7, error: [694.33235883]
# Prediction: [15.61999938], actual: 48.3, error: [1067.98244053]
# Prediction: [15.94079959], actual: 29.0, error: [170.54271529]
# Prediction: [15.65763994], actual: 24.0, error: [69.5949714]
# Prediction: [15.21441288], actual: 25.1, error: [97.72483276]
# Prediction: [15.12805537], actual: 31.5, error: [268.0405711]
# Prediction: [16.44437656], actual: 23.7, error: [52.64407156]
# Prediction: [16.2114245], actual: 23.3, error: [50.24790257]
# Prediction: [15.81322042], actual: 22.0, error: [38.27624152]
# Prediction: [15.63357548], actual: 20.1, error: [19.94894802]
# Prediction: [16.63504234], actual: 22.2, error: [30.96875377]
# Prediction: [16.60150802], actual: 23.7, error: [50.38858835]
# Prediction: [13.79897507], actual: 17.6, error: [14.44779048]
# Prediction: [13.51427558], actual: 18.5, error: [24.857448]
# Prediction: [13.49631077], actual: 24.3, error: [116.71970103]
# Prediction: [13.73652597], actual: 20.5, error: [45.744581]
# Prediction: [13.76099233], actual: 24.5, error: [115.32628574]
# Prediction: [13.34277497], actual: 26.2, error: [165.3082354]
# Prediction: [13.20737492], actual: 24.4, error: [125.27485609]
# Prediction: [13.72061428], actual: 24.8, error: [122.75278801]
# Prediction: [13.56628799], actual: 29.6, error: [257.0799209]
# Prediction: [13.17432452], actual: 42.8, error: [877.68064773]
# Prediction: [15.91281363], actual: 21.9, error: [35.84640062]
# Prediction: [15.79074036], actual: 20.9, error: [26.10453408]
# Prediction: [16.72951733], actual: 44.0, error: [743.67922532]
# Prediction: [19.26214993], actual: 50.0, error: [944.815427]
# Prediction: [19.60384848], actual: 36.0, error: [268.83378478]
# Prediction: [19.14327508], actual: 30.1, error: [120.04982091]
# Prediction: [19.0968979], actual: 33.8, error: [216.18121134]
# Prediction: [19.33304838], actual: 43.1, error: [564.86798934]
# Prediction: [19.41354211], actual: 48.8, error: [863.56390738]
# Prediction: [19.0638475], actual: 31.0, error: [142.47173661]
# Prediction: [19.35863579], actual: 36.5, error: [293.82636698]
# Prediction: [19.11822074], actual: 22.8, error: [13.5554985]
# Prediction: [19.56226893], actual: 30.7, error: [124.0490533]
# Prediction: [19.53721459], actual: 50.0, error: [927.98129467]
# Prediction: [19.23016567], actual: 43.5, error: [589.02485863]
# Prediction: [13.93825418], actual: 20.7, error: [45.72120656]
# Prediction: [14.08165029], actual: 21.1, error: [49.25723262]
# Prediction: [13.64186667], actual: 25.2, error: [133.59044607]
# Prediction: [13.74528246], actual: 24.4, error: [113.52300596]
# Prediction: [13.96863923], actual: 35.2, error: [450.77068021]
# Prediction: [14.57695097], actual: 32.4, error: [317.66107661]
# Prediction: [14.57695097], actual: 32.0, error: [303.56263739]
# Prediction: [14.98475033], actual: 33.2, error: [331.79532046]
# Prediction: [14.76086049], actual: 33.1, error: [336.32403804]
# Prediction: [14.57695097], actual: 29.1, error: [210.91895303]
# Prediction: [17.10167859], actual: 35.1, error: [323.93957352]
# Prediction: [17.61289374], actual: 45.4, error: [772.12327455]
# Prediction: [17.35062278], actual: 35.4, error: [325.7800182]
# Prediction: [18.1587585], actual: 46.0, error: [775.13472834]
# Prediction: [18.39085199], actual: 50.0, error: [999.13823783]
# Prediction: [16.84385436], actual: 32.2, error: [235.81120889]
# Prediction: [16.84385436], actual: 22.0, error: [26.58583785]
# Prediction: [15.35006838], actual: 20.1, error: [22.56185038]
# Prediction: [15.51203528], actual: 23.2, error: [59.10480159]
# Prediction: [15.51203528], actual: 22.3, error: [46.07646509]
# Prediction: [16.65266496], actual: 24.8, error: [66.37906819]
# Prediction: [13.08081609], actual: 28.5, error: [237.7512325]
# Prediction: [13.08081609], actual: 37.3, error: [586.56886935]
# Prediction: [13.08081609], actual: 27.9, error: [219.60821181]
# Prediction: [16.07308586], actual: 23.9, error: [61.26058498]
# Prediction: [16.07308586], actual: 21.7, error: [31.66216276]
# Prediction: [16.07308586], actual: 28.6, error: [156.92357792]
# Prediction: [16.28897964], actual: 27.1, error: [116.8781613]
# Prediction: [16.07308586], actual: 20.3, error: [17.86680316]
# Prediction: [18.72296867], actual: 22.5, error: [14.26596565]
# Prediction: [18.54492294], actual: 29.0, error: [109.30863634]
# Prediction: [17.51716194], actual: 24.8, error: [53.0397302]
# Prediction: [16.0408806], actual: 22.0, error: [35.51110403]
# Prediction: [16.68802886], actual: 26.4, error: [94.32238336]
# Prediction: [16.3244744], actual: 33.1, error: [281.41825909]
# Prediction: [14.00053241], actual: 36.1, error: [488.38646771]
# Prediction: [14.01759069], actual: 28.4, error: [206.8536977]
# Prediction: [13.82888353], actual: 33.4, error: [383.02859985]
# Prediction: [13.82888353], actual: 28.2, error: [206.52898857]
# Prediction: [13.82888353], actual: 22.8, error: [80.4809307]
# Prediction: [13.86406622], actual: 20.3, error: [41.42124361]
# Prediction: [14.97140943], actual: 16.1, error: [1.27371668]
# Prediction: [13.82888353], actual: 22.1, error: [68.41136765]
# Prediction: [13.86086779], actual: 19.4, error: [30.68198559]
# Prediction: [14.01599147], actual: 21.6, error: [57.51718535]
# Prediction: [13.89338513], actual: 23.8, error: [98.14101821]
# Prediction: [13.85447094], actual: 16.2, error: [5.50150656]
# Prediction: [14.15938759], actual: 17.8, error: [13.25405875]
# Prediction: [13.82888353], actual: 19.8, error: [35.65423189]
# Prediction: [13.91897254], actual: 23.1, error: [84.29126523]
# Prediction: [13.86459929], actual: 21.0, error: [50.91394327]
# Prediction: [12.70678237], actual: 23.8, error: [123.05947745]
# Prediction: [12.70678237], actual: 23.1, error: [108.01897277]
# Prediction: [12.70678237], actual: 20.4, error: [59.18559755]
# Prediction: [12.91195375], actual: 18.5, error: [31.22626087]
# Prediction: [12.70678237], actual: 25.0, error: [151.12319977]
# Prediction: [12.86832492], actual: 24.6, error: [137.63220012]
# Prediction: [12.70678237], actual: 23.0, error: [105.95032924]
# Prediction: [12.70678237], actual: 22.2, error: [90.12118103]
# Prediction: [16.00233073], actual: 19.3, error: [10.87462258]
# Prediction: [16.25209147], actual: 22.6, error: [40.29594274]
# Prediction: [16.36569752], actual: 19.8, error: [11.79443355]
# Prediction: [15.38503445], actual: 17.1, error: [2.94110684]
# Prediction: [16.47382857], actual: 19.4, error: [8.56247921]
# Prediction: [12.55703925], actual: 22.2, error: [92.98669195]
# Prediction: [12.55720451], actual: 20.7, error: [66.30511846]
# Prediction: [12.55320647], actual: 21.1, error: [73.04767959]
# Prediction: [12.55320647], actual: 19.5, error: [48.25794031]
# Prediction: [12.55432059], actual: 18.5, error: [35.35110363]
# Prediction: [12.55361161], actual: 20.6, error: [64.74436617]
# Prediction: [12.55320647], actual: 19.0, error: [41.56114678]
# Prediction: [12.55320647], actual: 18.7, error: [37.78307066]
# Prediction: [16.65577136], actual: 32.7, error: [257.41727271]
# Prediction: [16.5365456], actual: 16.5, error: [0.00133558]
# Prediction: [14.57695097], actual: 23.9, error: [86.91924316]
# Prediction: [15.05298343], actual: 31.2, error: [260.72614419]
# Prediction: [13.91484908], actual: 17.5, error: [12.85330715]
# Prediction: [14.27465859], actual: 17.2, error: [8.55762234]
# Prediction: [14.53470844], actual: 23.1, error: [73.36421942]
# Prediction: [15.45571191], actual: 24.5, error: [81.79914714]
# Prediction: [12.82023309], actual: 26.6, error: [189.88197623]
# Prediction: [12.61327394], actual: 22.9, error: [105.8167331]
# Prediction: [14.73719708], actual: 24.1, error: [87.66207859]
# Prediction: [14.16600543], actual: 18.6, error: [19.66030781]
# Prediction: [15.80114195], actual: 30.1, error: [204.45734152]
# Prediction: [12.54389126], actual: 18.2, error: [31.99156611]
# Prediction: [12.54749482], actual: 20.6, error: [64.84283971]
# Prediction: [12.56342545], actual: 17.8, error: [27.42171307]
# Prediction: [12.55617035], actual: 21.7, error: [83.6096207]
# Prediction: [12.55399009], actual: 22.7, error: [102.94151714]
# Prediction: [12.55649019], actual: 22.6, error: [100.87208929]
# Prediction: [12.56511528], actual: 25.0, error: [154.62635799]
# Prediction: [12.92281626], actual: 19.9, error: [48.68109298]
# Prediction: [12.56179425], actual: 20.8, error: [67.86803401]
# Prediction: [12.88192492], actual: 16.8, error: [15.3513123]
# Prediction: [12.85608981], actual: 21.9, error: [81.79231147]
# Prediction: [12.85352341], actual: 27.5, error: [214.51927646]
# Prediction: [13.51514177], actual: 21.9, error: [70.30584754]
# Prediction: [16.67369789], actual: 23.1, error: [41.29735883]
# Prediction: [12.56460353], actual: 50.0, error: [1401.40890869]
# Prediction: [12.56470482], actual: 50.0, error: [1401.40132553]
# Prediction: [12.55579187], actual: 50.0, error: [1402.06872265]
# Prediction: [12.65762141], actual: 50.0, error: [1394.45323839]
# Prediction: [12.97020914], actual: 50.0, error: [1371.20541099]
# Prediction: [12.55320647], actual: 13.8, error: [1.5544941]
# Prediction: [12.55320647], actual: 13.8, error: [1.5544941]
# Prediction: [12.55320647], actual: 15.0, error: [5.98679856]
# Prediction: [12.71117366], actual: 13.9, error: [1.41330806]
# Prediction: [12.55320647], actual: 13.3, error: [0.55770057]
# Prediction: [12.55320647], actual: 13.1, error: [0.29898316]
# Prediction: [12.55489098], actual: 10.2, error: [5.54551152]
# Prediction: [12.55320647], actual: 10.4, error: [4.63629812]
# Prediction: [12.55320647], actual: 10.9, error: [2.73309164]
# Prediction: [12.55320647], actual: 11.3, error: [1.57052646]
# Prediction: [12.55320647], actual: 12.3, error: [0.06411352]
# Prediction: [14.03184398], actual: 8.8, error: [27.37219142]
# Prediction: [12.55320647], actual: 7.2, error: [28.65681954]
# Prediction: [12.55320647], actual: 10.5, error: [4.21565682]
# Prediction: [12.55320647], actual: 7.4, error: [26.55553695]
# Prediction: [12.56598952], actual: 10.2, error: [5.59790639]
# Prediction: [12.55320647], actual: 11.5, error: [1.10924387]
# Prediction: [12.55452316], actual: 15.1, error: [6.47945235]
# Prediction: [12.56307895], actual: 23.2, error: [113.14408944]
# Prediction: [12.55320647], actual: 9.7, error: [8.14078718]
# Prediction: [12.55320647], actual: 13.8, error: [1.5544941]
# Prediction: [12.55320647], actual: 12.7, error: [0.02154834]
# Prediction: [12.55582918], actual: 13.1, error: [0.29612188]
# Prediction: [12.55320647], actual: 12.5, error: [0.00283093]
# Prediction: [12.55523214], actual: 8.5, error: [16.44490773]
# Prediction: [12.55320647], actual: 5.0, error: [57.05092803]
# Prediction: [13.13651197], actual: 6.3, error: [46.73789595]
# Average squared training error ($):  [165.81136685]
